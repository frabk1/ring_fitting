# %%
import os, numpy as np, matplotlib.pyplot as plt, ehtim as eh
from ringfit.extraction import rbp_visualization_frames

im = eh.image.load_fits(os.path.expanduser("~/Downloads/test.fits"))
base = im.imarr()

frames, pts_by_panel, R, iters = rbp_visualization_frames(
    im,
    n_panels=5,
    max_it=5000,
    threshold=.75,
    radius=35.0
)

fig, axes = plt.subplots(1, 5, figsize=(19, 4), constrained_layout=True)
for ax, pts, it in zip(axes, pts_by_panel, iters):
    ax.imshow(base, origin="lower", cmap="inferno")
    if len(pts):
        ax.scatter(pts[:, 0], pts[:, 1], s=12, c="black")
        for x, y in pts:
            ax.add_patch(plt.Circle((x, y), R, fill=False, edgecolor="black", linewidth=1))
    ax.set_title(f"iteration={it}")
    ax.set_xticks([]); ax.set_yticks([])
plt.show()
# Out:
# Loading fits image:  /Users/frankmyhre/Downloads/test.fits

# %%
pip install ringfit
# Out:
# Collecting ringfit
#   Downloading ringfit-0.4.8-py3-none-any.whl.metadata (185 bytes)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ringfit) (2.3.1)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ringfit) (1.16.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ringfit) (3.10.3)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ringfit) (11.3.0)
# Requirement already satisfied: ehtim in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ringfit) (1.2.10)
# Requirement already satisfied: astropy>=5.0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (7.1.0)
# Requirement already satisfied: skyfield in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (1.53)
# Requirement already satisfied: h5py in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (3.14.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (2.3.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (2.32.4)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (1.0.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (3.5)
# Requirement already satisfied: paramsurvey in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ehtim->ringfit) (0.4.21)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astropy>=5.0.4->ehtim->ringfit) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astropy>=5.0.4->ehtim->ringfit) (0.2025.7.28.0.41.50)
# Requirement already satisfied: PyYAML>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astropy>=5.0.4->ehtim->ringfit) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astropy>=5.0.4->ehtim->ringfit) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->ringfit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->ringfit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->ringfit) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->ringfit) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->ringfit) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->ringfit) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->ringfit) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->ehtim->ringfit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->ehtim->ringfit) (2025.2)
# Requirement already satisfied: hdrhistogram in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paramsurvey->ehtim->ringfit) (0.10.3)
# Requirement already satisfied: pandas-appender>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paramsurvey->ehtim->ringfit) (0.9.9)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paramsurvey->ehtim->ringfit) (7.0.0)
# Requirement already satisfied: pbr>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from hdrhistogram->paramsurvey->ehtim->ringfit) (6.1.1)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pbr>=1.4->hdrhistogram->paramsurvey->ehtim->ringfit) (65.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->ehtim->ringfit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->ehtim->ringfit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->ehtim->ringfit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->ehtim->ringfit) (2025.7.14)
# Requirement already satisfied: jplephem>=2.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from skyfield->ehtim->ringfit) (2.23)
# Requirement already satisfied: sgp4>=2.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from skyfield->ehtim->ringfit) (2.24)
# Downloading ringfit-0.4.8-py3-none-any.whl (11 kB)
# Installing collected packages: ringfit
# Successfully installed ringfit-0.4.8
# Note: you may need to restart the kernel to use updated packages.
